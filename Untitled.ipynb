# %%
from model import create_laplacian_arch

# %%
model = create_laplacian_arch(256,256)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input image (InputLayer)        [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 256, 256, 3)  0           input image[0][0]
# __________________________________________________________________________________________________
# down_image1 (Resizing)          (None, 128, 128, 3)  0           lambda[0][0]
# __________________________________________________________________________________________________
# up_image (Resizing)             (None, 256, 256, 3)  0           down_image1[0][0]
# __________________________________________________________________________________________________
# rescaling_6 (Rescaling)         (None, 256, 256, 3)  0           input image[0][0]
# ...
