# %%
import tensorflow as tf
from tensorflow.keras.layers import Input,Dense,Reshape,Flatten,Dropout,Subtract,Add
from tensorflow.keras.layers import BatchNormalization,Activation,ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU,Lambda
from tensorflow.keras.layers.experimental.preprocessing import Resizing,Rescaling
from tensorflow.keras.layers import UpSampling2D,Conv2D,Conv2DTranspose,MaxPooling2D,AveragePooling2D
from tensorflow.keras.models import Sequential,Model,load_model
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
import matplotlib.pyplot as plt

# %%
from tensorflow_addons.image.filters import gaussian_filter2d

# %%
def gaussian_filter_layer(image):
    return gaussian_filter2d(image,filter_shape=(5,5))

# %%
height,width,channels = 256,256,3
image = Input(shape=(height,width,channels),name='input image')
down_image1 = Lambda(lambda image:gaussian_filter2d(image,filter_shape=(5,5)))(image)
down_image1 = Resizing(height//2,width//2,interpolation='bilinear',name='down_image1')(down_image1)
down_image2 = Lambda(lambda image:gaussian_filter2d(image,filter_shape=(5,5)))(down_image1)
down_image2 = Resizing(height//4,width//4,interpolation='bilinear',name='down_image2')(down_image2)
down_image3 = Lambda(lambda image:gaussian_filter2d(image,filter_shape=(5,5)))(down_image2)
down_image3 = Resizing(height//8,width//8,interpolation='bilinear',name='down_image3')(down_image3)
up_image = Resizing(height,width,interpolation="bilinear",name='up_image')(down_image1)
up_image1 = Resizing(height//2,width//2,interpolation="bilinear",name='up_image1')(down_image2)
up_image2 = Resizing(height//4,width//4,interpolation="bilinear",name='up_image2')(down_image3)

subtracted = Subtract()([down_image2,up_image2])
subtracted = Rescaling(scale=1./255,name='model2_input')(subtracted)
x = subtracted

filters = 32
for i in range(3):
    x = Conv2D(filters=filters,kernel_size=(3,3),strides=2,padding='same',name=f"model2_conv{i}")(x)
    x = LeakyReLU(alpha=0.2)(x)
    x = BatchNormalization()(x)
    filters *= 2

for i in range(3):
    x = Conv2DTranspose(filters=filters,kernel_size=(3,3),strides=2,padding='same',name=f"model2_convtrans{i}")(x)
    x = LeakyReLU(alpha=0.2)(x)
    x = BatchNormalization()(x)
    filters /= 2
    
x = Conv2D(filters=channels,kernel_size=(3,3),strides=1,activation='linear',padding='same',name=f"model2_conv_final")(x)
model2_output = Add()([x, up_image2])
model2_output_resized = Resizing(height//2,width//2,interpolation='bilinear')(model2_output)

subtracted = Subtract()([down_image1,up_image1])
subtracted = Rescaling(scale=1./255,name='model1_input')(subtracted)
x = subtracted

filters = 32
for i in range(4):
    x = Conv2D(filters=filters,kernel_size=(3,3),strides=2,padding='same',name=f"model1_conv{i}")(x)
    x = LeakyReLU(alpha=0.2)(x)
    x = BatchNormalization()(x)
    filters *= 2

for i in range(4):
    x = Conv2DTranspose(filters=filters,kernel_size=(3,3),strides=2,padding='same',name=f"model1_convtrans{i}")(x)
    x = LeakyReLU(alpha=0.2)(x)
    x = BatchNormalization()(x)
    filters /= 2
x = Conv2D(filters=channels,kernel_size=(3,3),strides=1,activation='linear',padding='same',name=f"model1_conv_final")(x) 
model1_output = Add()([x, model2_output_resized])
model1_output_resized = Resizing(height,width,interpolation='bilinear')(model1_output)

subtracted = Subtract()([image,up_image])
subtracted = Rescaling(scale=1./255,name='model_input')(subtracted)
x = subtracted
filters = 32
for i in range(5):
    x = Conv2D(filters=filters,kernel_size=(3,3),strides=2,padding='same',name=f"model_conv{i}")(x)
    x = LeakyReLU(alpha=0.2)(x)
    x = BatchNormalization()(x)
    filters *= 2

for i in range(5):
    x = Conv2DTranspose(filters=filters,kernel_size=(3,3),strides=2,padding='same',name=f"model_convtrans{i}")(x)
    x = LeakyReLU(alpha=0.2)(x)
    x = BatchNormalization()(x)
    filters /= 2
x = Conv2D(filters=channels,kernel_size=(3,3),strides=1,activation='linear',padding='same',name=f"model_conv_final")(x) 
model_output = Add()([x, model1_output_resized])


model = Model(inputs=image,outputs=[model2_output,down_image2,model1_output,down_image1,model_output,image])
loss = tf.keras.losses.MeanSquaredError()(model2_output, down_image2) +\
                     tf.keras.losses.MeanSquaredError()(model1_output, down_image1) +\
                     tf.keras.losses.MeanSquaredError()(model_output, image)
model.add_loss(loss)

# %%
model.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input image (InputLayer)        [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 256, 256, 3)  0           input image[0][0]
# __________________________________________________________________________________________________
# down_image1 (Resizing)          (None, 128, 128, 3)  0           lambda_27[0][0]
# __________________________________________________________________________________________________
# up_image (Resizing)             (None, 256, 256, 3)  0           down_image1[0][0]
# __________________________________________________________________________________________________
# subtract_29 (Subtract)          (None, 256, 256, 3)  0           input image[0][0]
#                                                                  up_image[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 128, 128, 3)  0           down_image1[0][0]
# __________________________________________________________________________________________________
# model_input (Rescaling)         (None, 256, 256, 3)  0           subtract_29[0][0]
# __________________________________________________________________________________________________
# down_image2 (Resizing)          (None, 64, 64, 3)    0           lambda_28[0][0]
# __________________________________________________________________________________________________
# model_conv0 (Conv2D)            (None, 128, 128, 32) 896         model_input[0][0]
# __________________________________________________________________________________________________
# up_image1 (Resizing)            (None, 128, 128, 3)  0           down_image2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_230 (LeakyReLU)     (None, 128, 128, 32) 0           model_conv0[0][0]
# __________________________________________________________________________________________________
# subtract_28 (Subtract)          (None, 128, 128, 3)  0           down_image1[0][0]
#                                                                  up_image1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_230 (BatchN (None, 128, 128, 32) 128         leaky_re_lu_230[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 64, 64, 3)    0           down_image2[0][0]
# __________________________________________________________________________________________________
# model1_input (Rescaling)        (None, 128, 128, 3)  0           subtract_28[0][0]
# __________________________________________________________________________________________________
# model_conv1 (Conv2D)            (None, 64, 64, 64)   18496       batch_normalization_230[0][0]
# __________________________________________________________________________________________________
# down_image3 (Resizing)          (None, 32, 32, 3)    0           lambda_29[0][0]
# __________________________________________________________________________________________________
# model1_conv0 (Conv2D)           (None, 64, 64, 32)   896         model1_input[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_231 (LeakyReLU)     (None, 64, 64, 64)   0           model_conv1[0][0]
# __________________________________________________________________________________________________
# up_image2 (Resizing)            (None, 64, 64, 3)    0           down_image3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_222 (LeakyReLU)     (None, 64, 64, 32)   0           model1_conv0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_231 (BatchN (None, 64, 64, 64)   256         leaky_re_lu_231[0][0]
# __________________________________________________________________________________________________
# subtract_27 (Subtract)          (None, 64, 64, 3)    0           down_image2[0][0]
#                                                                  up_image2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_222 (BatchN (None, 64, 64, 32)   128         leaky_re_lu_222[0][0]
# __________________________________________________________________________________________________
# model_conv2 (Conv2D)            (None, 32, 32, 128)  73856       batch_normalization_231[0][0]
# __________________________________________________________________________________________________
# model2_input (Rescaling)        (None, 64, 64, 3)    0           subtract_27[0][0]
# __________________________________________________________________________________________________
# model1_conv1 (Conv2D)           (None, 32, 32, 64)   18496       batch_normalization_222[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_232 (LeakyReLU)     (None, 32, 32, 128)  0           model_conv2[0][0]
# __________________________________________________________________________________________________
# model2_conv0 (Conv2D)           (None, 32, 32, 32)   896         model2_input[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_223 (LeakyReLU)     (None, 32, 32, 64)   0           model1_conv1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_232 (BatchN (None, 32, 32, 128)  512         leaky_re_lu_232[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_216 (LeakyReLU)     (None, 32, 32, 32)   0           model2_conv0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_223 (BatchN (None, 32, 32, 64)   256         leaky_re_lu_223[0][0]
# __________________________________________________________________________________________________
# model_conv3 (Conv2D)            (None, 16, 16, 256)  295168      batch_normalization_232[0][0]
# __________________________________________________________________________________________________
# batch_normalization_216 (BatchN (None, 32, 32, 32)   128         leaky_re_lu_216[0][0]
# __________________________________________________________________________________________________
# model1_conv2 (Conv2D)           (None, 16, 16, 128)  73856       batch_normalization_223[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_233 (LeakyReLU)     (None, 16, 16, 256)  0           model_conv3[0][0]
# __________________________________________________________________________________________________
# model2_conv1 (Conv2D)           (None, 16, 16, 64)   18496       batch_normalization_216[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_224 (LeakyReLU)     (None, 16, 16, 128)  0           model1_conv2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_233 (BatchN (None, 16, 16, 256)  1024        leaky_re_lu_233[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_217 (LeakyReLU)     (None, 16, 16, 64)   0           model2_conv1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_224 (BatchN (None, 16, 16, 128)  512         leaky_re_lu_224[0][0]
# __________________________________________________________________________________________________
# model_conv4 (Conv2D)            (None, 8, 8, 512)    1180160     batch_normalization_233[0][0]
# __________________________________________________________________________________________________
# batch_normalization_217 (BatchN (None, 16, 16, 64)   256         leaky_re_lu_217[0][0]
# __________________________________________________________________________________________________
# model1_conv3 (Conv2D)           (None, 8, 8, 256)    295168      batch_normalization_224[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_234 (LeakyReLU)     (None, 8, 8, 512)    0           model_conv4[0][0]
# __________________________________________________________________________________________________
# model2_conv2 (Conv2D)           (None, 8, 8, 128)    73856       batch_normalization_217[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_225 (LeakyReLU)     (None, 8, 8, 256)    0           model1_conv3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_234 (BatchN (None, 8, 8, 512)    2048        leaky_re_lu_234[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_218 (LeakyReLU)     (None, 8, 8, 128)    0           model2_conv2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_225 (BatchN (None, 8, 8, 256)    1024        leaky_re_lu_225[0][0]
# __________________________________________________________________________________________________
# model_convtrans0 (Conv2DTranspo (None, 16, 16, 1024) 4719616     batch_normalization_234[0][0]
# __________________________________________________________________________________________________
# batch_normalization_218 (BatchN (None, 8, 8, 128)    512         leaky_re_lu_218[0][0]
# __________________________________________________________________________________________________
# model1_convtrans0 (Conv2DTransp (None, 16, 16, 512)  1180160     batch_normalization_225[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_235 (LeakyReLU)     (None, 16, 16, 1024) 0           model_convtrans0[0][0]
# __________________________________________________________________________________________________
# model2_convtrans0 (Conv2DTransp (None, 16, 16, 256)  295168      batch_normalization_218[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_226 (LeakyReLU)     (None, 16, 16, 512)  0           model1_convtrans0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_235 (BatchN (None, 16, 16, 1024) 4096        leaky_re_lu_235[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_219 (LeakyReLU)     (None, 16, 16, 256)  0           model2_convtrans0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_226 (BatchN (None, 16, 16, 512)  2048        leaky_re_lu_226[0][0]
# __________________________________________________________________________________________________
# model_convtrans1 (Conv2DTranspo (None, 32, 32, 512)  4719104     batch_normalization_235[0][0]
# __________________________________________________________________________________________________
# batch_normalization_219 (BatchN (None, 16, 16, 256)  1024        leaky_re_lu_219[0][0]
# __________________________________________________________________________________________________
# model1_convtrans1 (Conv2DTransp (None, 32, 32, 256)  1179904     batch_normalization_226[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_236 (LeakyReLU)     (None, 32, 32, 512)  0           model_convtrans1[0][0]
# __________________________________________________________________________________________________
# model2_convtrans1 (Conv2DTransp (None, 32, 32, 128)  295040      batch_normalization_219[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_227 (LeakyReLU)     (None, 32, 32, 256)  0           model1_convtrans1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_236 (BatchN (None, 32, 32, 512)  2048        leaky_re_lu_236[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_220 (LeakyReLU)     (None, 32, 32, 128)  0           model2_convtrans1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_227 (BatchN (None, 32, 32, 256)  1024        leaky_re_lu_227[0][0]
# __________________________________________________________________________________________________
# model_convtrans2 (Conv2DTranspo (None, 64, 64, 256)  1179904     batch_normalization_236[0][0]
# __________________________________________________________________________________________________
# batch_normalization_220 (BatchN (None, 32, 32, 128)  512         leaky_re_lu_220[0][0]
# __________________________________________________________________________________________________
# model1_convtrans2 (Conv2DTransp (None, 64, 64, 128)  295040      batch_normalization_227[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_237 (LeakyReLU)     (None, 64, 64, 256)  0           model_convtrans2[0][0]
# __________________________________________________________________________________________________
# model2_convtrans2 (Conv2DTransp (None, 64, 64, 64)   73792       batch_normalization_220[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_228 (LeakyReLU)     (None, 64, 64, 128)  0           model1_convtrans2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_237 (BatchN (None, 64, 64, 256)  1024        leaky_re_lu_237[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_221 (LeakyReLU)     (None, 64, 64, 64)   0           model2_convtrans2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_228 (BatchN (None, 64, 64, 128)  512         leaky_re_lu_228[0][0]
# __________________________________________________________________________________________________
# model_convtrans3 (Conv2DTranspo (None, 128, 128, 128 295040      batch_normalization_237[0][0]
# __________________________________________________________________________________________________
# batch_normalization_221 (BatchN (None, 64, 64, 64)   256         leaky_re_lu_221[0][0]
# __________________________________________________________________________________________________
# model1_convtrans3 (Conv2DTransp (None, 128, 128, 64) 73792       batch_normalization_228[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_238 (LeakyReLU)     (None, 128, 128, 128 0           model_convtrans3[0][0]
# __________________________________________________________________________________________________
# model2_conv_final (Conv2D)      (None, 64, 64, 3)    1731        batch_normalization_221[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_229 (LeakyReLU)     (None, 128, 128, 64) 0           model1_convtrans3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_238 (BatchN (None, 128, 128, 128 512         leaky_re_lu_238[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 64, 64, 3)    0           model2_conv_final[0][0]
#                                                                  up_image2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_229 (BatchN (None, 128, 128, 64) 256         leaky_re_lu_229[0][0]
# __________________________________________________________________________________________________
# model_convtrans4 (Conv2DTranspo (None, 256, 256, 64) 73792       batch_normalization_238[0][0]
# __________________________________________________________________________________________________
# model1_conv_final (Conv2D)      (None, 128, 128, 3)  1731        batch_normalization_229[0][0]
# __________________________________________________________________________________________________
# resizing_18 (Resizing)          (None, 128, 128, 3)  0           add_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_239 (LeakyReLU)     (None, 256, 256, 64) 0           model_convtrans4[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 128, 128, 3)  0           model1_conv_final[0][0]
#                                                                  resizing_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_239 (BatchN (None, 256, 256, 64) 256         leaky_re_lu_239[0][0]
# __________________________________________________________________________________________________
# model_conv_final (Conv2D)       (None, 256, 256, 3)  1731        batch_normalization_239[0][0]
# __________________________________________________________________________________________________
# resizing_19 (Resizing)          (None, 256, 256, 3)  0           add_28[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 256, 256, 3)  0           model_conv_final[0][0]
#                                                                  resizing_19[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor (TFOpLambd (None, 64, 64, 3)    0           down_image2[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_1 (TFOpLam (None, 64, 64, 3)    0           add_27[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_3 (TFOpLam (None, 128, 128, 3)  0           down_image1[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_4 (TFOpLam (None, 128, 128, 3)  0           add_28[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_2 (TFOpLam (None, 64, 64, 3)    0           tf.convert_to_tensor[0][0]
# __________________________________________________________________________________________________
# tf.cast (TFOpLambda)            (None, 64, 64, 3)    0           tf.convert_to_tensor_1[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_5 (TFOpLam (None, 128, 128, 3)  0           tf.convert_to_tensor_3[0][0]
# __________________________________________________________________________________________________
# tf.cast_4 (TFOpLambda)          (None, 128, 128, 3)  0           tf.convert_to_tensor_4[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_6 (TFOpLam (None, 256, 256, 3)  0           input image[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_7 (TFOpLam (None, 256, 256, 3)  0           add_29[0][0]
# __________________________________________________________________________________________________
# tf.math.squared_difference (TFO (None, 64, 64, 3)    0           tf.convert_to_tensor_2[0][0]
#                                                                  tf.cast[0][0]
# __________________________________________________________________________________________________
# tf.math.squared_difference_1 (T (None, 128, 128, 3)  0           tf.convert_to_tensor_5[0][0]
#                                                                  tf.cast_4[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_8 (TFOpLam (None, 256, 256, 3)  0           tf.convert_to_tensor_6[0][0]
# __________________________________________________________________________________________________
# tf.cast_8 (TFOpLambda)          (None, 256, 256, 3)  0           tf.convert_to_tensor_7[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean (TFOpLambda (None, 64, 64)       0           tf.math.squared_difference[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_1 (TFOpLamb (None, 128, 128)     0           tf.math.squared_difference_1[0][0
# __________________________________________________________________________________________________
# tf.math.squared_difference_2 (T (None, 256, 256, 3)  0           tf.convert_to_tensor_8[0][0]
#                                                                  tf.cast_8[0][0]
# __________________________________________________________________________________________________
# tf.cast_1 (TFOpLambda)          (None, 64, 64)       0           tf.math.reduce_mean[0][0]
# __________________________________________________________________________________________________
# tf.cast_5 (TFOpLambda)          (None, 128, 128)     0           tf.math.reduce_mean_1[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_2 (TFOpLamb (None, 256, 256)     0           tf.math.squared_difference_2[0][0
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, 64, 64)       0           tf.cast_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) (None, 128, 128)     0           tf.cast_5[0][0]
# __________________________________________________________________________________________________
# tf.cast_9 (TFOpLambda)          (None, 256, 256)     0           tf.math.reduce_mean_2[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum (TFOpLambda) ()                   0           tf.math.multiply[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.size (TFOpLambda)  ()                   0           tf.math.multiply[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_2 (TFOpLambd ()                   0           tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.size_1 (TFOpLambda ()                   0           tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None, 256, 256)     0           tf.cast_9[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_1 (TFOpLambd ()                   0           tf.math.reduce_sum[0][0]
# __________________________________________________________________________________________________
# tf.cast_2 (TFOpLambda)          ()                   0           tf.compat.v1.size[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_3 (TFOpLambd ()                   0           tf.math.reduce_sum_2[0][0]
# __________________________________________________________________________________________________
# tf.cast_6 (TFOpLambda)          ()                   0           tf.compat.v1.size_1[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_4 (TFOpLambd ()                   0           tf.math.multiply_2[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.size_2 (TFOpLambda ()                   0           tf.math.multiply_2[0][0]
# __________________________________________________________________________________________________
# tf.math.divide_no_nan (TFOpLamb ()                   0           tf.math.reduce_sum_1[0][0]
#                                                                  tf.cast_2[0][0]
# __________________________________________________________________________________________________
# tf.math.divide_no_nan_1 (TFOpLa ()                   0           tf.math.reduce_sum_3[0][0]
#                                                                  tf.cast_6[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_5 (TFOpLambd ()                   0           tf.math.reduce_sum_4[0][0]
# __________________________________________________________________________________________________
# tf.cast_10 (TFOpLambda)         ()                   0           tf.compat.v1.size_2[0][0]
# __________________________________________________________________________________________________
# tf.cast_3 (TFOpLambda)          ()                   0           tf.math.divide_no_nan[0][0]
# __________________________________________________________________________________________________
# tf.cast_7 (TFOpLambda)          ()                   0           tf.math.divide_no_nan_1[0][0]
# __________________________________________________________________________________________________
# tf.math.divide_no_nan_2 (TFOpLa ()                   0           tf.math.reduce_sum_5[0][0]
#                                                                  tf.cast_10[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd ()                   0           tf.cast_3[0][0]
#                                                                  tf.cast_7[0][0]
# __________________________________________________________________________________________________
# tf.cast_11 (TFOpLambda)         ()                   0           tf.math.divide_no_nan_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam ()                   0           tf.__operators__.add[0][0]
#                                                                  tf.cast_11[0][0]
# __________________________________________________________________________________________________
# add_loss (AddLoss)              ()                   0           tf.__operators__.add_1[0][0]
# ==================================================================================================
# Total params: 16,456,137
# Trainable params: 16,445,961
# Non-trainable params: 10,176
# __________________________________________________________________________________________________

# %%
def custom_loss(y_true, y_pred):
    print(y_pred.shape,y_true.shape)
    #model2_output,down_image2,model1_output,down_image1,model_output,image = outputs
    loss = tf.add(tf.square(tf.subtract(y_pred[0],y_pred[1])), \
    tf.square(tf.subtract(y_pred[2],y_pred[3])),tf.square(tf.subtract(y_pred[4],y_pred[5])))
    return tf.reduce_mean(loss,axis=-1)

# %%
model.compile(optimizer='adam')

# %%
train_datagen = ImageDataGenerator()
train_generator = train_datagen.flow_from_directory(r'D://python3/mvtec_anomaly_detection/bottle/train',color_mode='rgb',\
                                 class_mode='input',batch_size=4,shuffle=True,target_size=(256,256))
# Out:
# Found 209 images belonging to 1 classes.

# %%
model.fit(train_generator,epochs=100,steps_per_epoch=len(train_generator))
# Out:
# Epoch 1/100
# 53/53 [==============================] - 171s 3s/step - loss: 223.1545
# Epoch 2/100
# 53/53 [==============================] - 167s 3s/step - loss: 72.3467
# Epoch 3/100
# 53/53 [==============================] - 166s 3s/step - loss: 56.3411
# Epoch 4/100
# 53/53 [==============================] - 166s 3s/step - loss: 46.9895
# Epoch 5/100
# 53/53 [==============================] - 166s 3s/step - loss: 41.9149
# Epoch 6/100
# 53/53 [==============================] - 165s 3s/step - loss: 38.5420
# Epoch 7/100
# 53/53 [==============================] - 165s 3s/step - loss: 36.2735
# Epoch 8/100
# 53/53 [==============================] - 166s 3s/step - loss: 34.3772
# Epoch 9/100
# 53/53 [==============================] - 165s 3s/step - loss: 32.3979
# Epoch 10/100
# 53/53 [==============================] - 166s 3s/step - loss: 31.0144
# Epoch 11/100
# 53/53 [==============================] - 165s 3s/step - loss: 29.5244
# Epoch 12/100
# 53/53 [==============================] - 165s 3s/step - loss: 28.1044
# Epoch 13/100
#  7/53 [==>...........................] - ETA: 2:28 - loss: 26.9233
