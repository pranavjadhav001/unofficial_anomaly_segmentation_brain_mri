# %%
import tensorflow as tf
from tensorflow.keras.layers import Input,Dense,Reshape,Flatten,Dropout,Subtract,Add
from tensorflow.keras.layers import BatchNormalization,Activation,ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU,Lambda
from tensorflow.keras.layers.experimental.preprocessing import Resizing,Rescaling
from tensorflow.keras.layers import UpSampling2D,Conv2D,Conv2DTranspose,MaxPooling2D,AveragePooling2D
from tensorflow.keras.models import Sequential,Model,load_model
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
from tensorflow_addons.image.filters import gaussian_filter2d

# %%
def gaussian_filter_layer(image):
    return gaussian_filter2d(image,filter_shape=(5,5))

# %%
height,width,channels = 512,512,3
image = Input(shape=(height,width,channels),name='input image')
down_image1 = Lambda(lambda image:gaussian_filter2d(image,filter_shape=(5,5)))(image)
down_image1 = Resizing(height//2,width//2,interpolation='bilinear',name='down_image1')(down_image1)
down_image2 = Lambda(lambda image:gaussian_filter2d(image,filter_shape=(5,5)))(down_image1)
down_image2 = Resizing(height//4,width//4,interpolation='bilinear',name='down_image2')(down_image2)
down_image3 = Lambda(lambda image:gaussian_filter2d(image,filter_shape=(5,5)))(down_image2)
down_image3 = Resizing(height//8,width//8,interpolation='bilinear',name='down_image3')(down_image3)
up_image = Resizing(height,width,interpolation="bilinear",name='up_image')(down_image1)
up_image1 = Resizing(height//2,width//2,interpolation="bilinear",name='up_image1')(down_image2)
up_image2 = Resizing(height//4,width//4,interpolation="bilinear",name='up_image2')(down_image3)

subtracted = Subtract()([down_image2,up_image2])
subtracted = Rescaling(scale=1./255,name='model2_input')(subtracted)
x = subtracted

filters = 32
for i in range(3):
    x = Conv2D(filters=filters,kernel_size=(3,3),strides=2,padding='same',name=f"model2_conv{i}")(x)
    x = LeakyReLU(alpha=0.2)(x)
    x = BatchNormalization()(x)
    filters *= 2

for i in range(3):
    x = Conv2DTranspose(filters=filters,kernel_size=(3,3),strides=2,padding='same',name=f"model2_convtrans{i}")(x)
    x = LeakyReLU(alpha=0.2)(x)
    x = BatchNormalization()(x)
    filters /= 2
    
x = Conv2D(filters=channels,kernel_size=(3,3),strides=1,activation='linear',padding='same',name=f"model2_conv_final")(x)
model1_output = Add()([x, up_image2])
model2_output = Resizing(height//2,width//2,interpolation='bilinear')(model1_output)

subtracted = Subtract()([down_image1,up_image1])
subtracted = Rescaling(scale=1./255,name='model1_input')(subtracted)
x = subtracted

filters = 32
for i in range(4):
    x = Conv2D(filters=filters,kernel_size=(3,3),strides=2,padding='same',name=f"model1_conv{i}")(x)
    x = LeakyReLU(alpha=0.2)(x)
    x = BatchNormalization()(x)
    filters *= 2

for i in range(4):
    x = Conv2DTranspose(filters=filters,kernel_size=(3,3),strides=2,padding='same',name=f"model1_convtrans{i}")(x)
    x = LeakyReLU(alpha=0.2)(x)
    x = BatchNormalization()(x)
    filters /= 2
x = Conv2D(filters=channels,kernel_size=(3,3),strides=1,activation='linear',padding='same',name=f"model1_conv_final")(x) 
model1_output = Add()([x, model2_output])
model1_output = Resizing(height,width,interpolation='bilinear')(model1_output)

subtracted = Subtract()([image,up_image])
subtracted = Rescaling(scale=1./255,name='model_input')(subtracted)
x = subtracted
filters = 32
for i in range(5):
    x = Conv2D(filters=filters,kernel_size=(3,3),strides=2,padding='same',name=f"model_conv{i}")(x)
    x = LeakyReLU(alpha=0.2)(x)
    x = BatchNormalization()(x)
    filters *= 2

for i in range(5):
    x = Conv2DTranspose(filters=filters,kernel_size=(3,3),strides=2,padding='same',name=f"model_convtrans{i}")(x)
    x = LeakyReLU(alpha=0.2)(x)
    x = BatchNormalization()(x)
    filters /= 2
x = Conv2D(filters=channels,kernel_size=(3,3),strides=1,activation='linear',padding='same',name=f"model_conv_final")(x) 
model_output = Add()([x, model1_output])

model = Model(inputs=image,outputs=model_output)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input image (InputLayer)        [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 512, 512, 3)  0           input image[0][0]
# __________________________________________________________________________________________________
# down_image1 (Resizing)          (None, 256, 256, 3)  0           lambda_9[0][0]
# __________________________________________________________________________________________________
# up_image (Resizing)             (None, 512, 512, 3)  0           down_image1[0][0]
# __________________________________________________________________________________________________
# subtract_8 (Subtract)           (None, 512, 512, 3)  0           input image[0][0]
#                                                                  up_image[0][0]
# __________________________________________________________________________________________________
# model_input (Rescaling)         (None, 512, 512, 3)  0           subtract_8[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 256, 256, 3)  0           down_image1[0][0]
# __________________________________________________________________________________________________
# model_conv0 (Conv2D)            (None, 256, 256, 32) 896         model_input[0][0]
# __________________________________________________________________________________________________
# down_image2 (Resizing)          (None, 128, 128, 3)  0           lambda_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)      (None, 256, 256, 32) 0           model_conv0[0][0]
# __________________________________________________________________________________________________
# up_image1 (Resizing)            (None, 256, 256, 3)  0           down_image2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 256, 256, 32) 128         leaky_re_lu_68[0][0]
# __________________________________________________________________________________________________
# subtract_7 (Subtract)           (None, 256, 256, 3)  0           down_image1[0][0]
#                                                                  up_image1[0][0]
# __________________________________________________________________________________________________
# model_conv1 (Conv2D)            (None, 128, 128, 64) 18496       batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# model1_input (Rescaling)        (None, 256, 256, 3)  0           subtract_7[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 128, 128, 3)  0           down_image2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_69 (LeakyReLU)      (None, 128, 128, 64) 0           model_conv1[0][0]
# __________________________________________________________________________________________________
# model1_conv0 (Conv2D)           (None, 128, 128, 32) 896         model1_input[0][0]
# __________________________________________________________________________________________________
# down_image3 (Resizing)          (None, 64, 64, 3)    0           lambda_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 128, 128, 64) 256         leaky_re_lu_69[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)      (None, 128, 128, 32) 0           model1_conv0[0][0]
# __________________________________________________________________________________________________
# up_image2 (Resizing)            (None, 128, 128, 3)  0           down_image3[0][0]
# __________________________________________________________________________________________________
# model_conv2 (Conv2D)            (None, 64, 64, 128)  73856       batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 128, 128, 32) 128         leaky_re_lu_60[0][0]
# __________________________________________________________________________________________________
# subtract_6 (Subtract)           (None, 128, 128, 3)  0           down_image2[0][0]
#                                                                  up_image2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_70 (LeakyReLU)      (None, 64, 64, 128)  0           model_conv2[0][0]
# __________________________________________________________________________________________________
# model1_conv1 (Conv2D)           (None, 64, 64, 64)   18496       batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# model2_input (Rescaling)        (None, 128, 128, 3)  0           subtract_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 64, 64, 128)  512         leaky_re_lu_70[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)      (None, 64, 64, 64)   0           model1_conv1[0][0]
# __________________________________________________________________________________________________
# model2_conv0 (Conv2D)           (None, 64, 64, 32)   896         model2_input[0][0]
# __________________________________________________________________________________________________
# model_conv3 (Conv2D)            (None, 32, 32, 256)  295168      batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 64, 64, 64)   256         leaky_re_lu_61[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 64, 64, 32)   0           model2_conv0[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_71 (LeakyReLU)      (None, 32, 32, 256)  0           model_conv3[0][0]
# __________________________________________________________________________________________________
# model1_conv2 (Conv2D)           (None, 32, 32, 128)  73856       batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 64, 64, 32)   128         leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 32, 32, 256)  1024        leaky_re_lu_71[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)      (None, 32, 32, 128)  0           model1_conv2[0][0]
# __________________________________________________________________________________________________
# model2_conv1 (Conv2D)           (None, 32, 32, 64)   18496       batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# model_conv4 (Conv2D)            (None, 16, 16, 512)  1180160     batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 32, 32, 128)  512         leaky_re_lu_62[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 32, 32, 64)   0           model2_conv1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_72 (LeakyReLU)      (None, 16, 16, 512)  0           model_conv4[0][0]
# __________________________________________________________________________________________________
# model1_conv3 (Conv2D)           (None, 16, 16, 256)  295168      batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 32, 32, 64)   256         leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 16, 16, 512)  2048        leaky_re_lu_72[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)      (None, 16, 16, 256)  0           model1_conv3[0][0]
# __________________________________________________________________________________________________
# model2_conv2 (Conv2D)           (None, 16, 16, 128)  73856       batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# model_convtrans0 (Conv2DTranspo (None, 32, 32, 1024) 4719616     batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 16, 16, 256)  1024        leaky_re_lu_63[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 16, 16, 128)  0           model2_conv2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_73 (LeakyReLU)      (None, 32, 32, 1024) 0           model_convtrans0[0][0]
# __________________________________________________________________________________________________
# model1_convtrans0 (Conv2DTransp (None, 32, 32, 512)  1180160     batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 16, 16, 128)  512         leaky_re_lu_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 32, 32, 1024) 4096        leaky_re_lu_73[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)      (None, 32, 32, 512)  0           model1_convtrans0[0][0]
# __________________________________________________________________________________________________
# model2_convtrans0 (Conv2DTransp (None, 32, 32, 256)  295168      batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# model_convtrans1 (Conv2DTranspo (None, 64, 64, 512)  4719104     batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 32, 32, 512)  2048        leaky_re_lu_64[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)      (None, 32, 32, 256)  0           model2_convtrans0[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_74 (LeakyReLU)      (None, 64, 64, 512)  0           model_convtrans1[0][0]
# __________________________________________________________________________________________________
# model1_convtrans1 (Conv2DTransp (None, 64, 64, 256)  1179904     batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 32, 32, 256)  1024        leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 64, 64, 512)  2048        leaky_re_lu_74[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)      (None, 64, 64, 256)  0           model1_convtrans1[0][0]
# __________________________________________________________________________________________________
# model2_convtrans1 (Conv2DTransp (None, 64, 64, 128)  295040      batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# model_convtrans2 (Conv2DTranspo (None, 128, 128, 256 1179904     batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 64, 64, 256)  1024        leaky_re_lu_65[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, 64, 64, 128)  0           model2_convtrans1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_75 (LeakyReLU)      (None, 128, 128, 256 0           model_convtrans2[0][0]
# __________________________________________________________________________________________________
# model1_convtrans2 (Conv2DTransp (None, 128, 128, 128 295040      batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 64, 64, 128)  512         leaky_re_lu_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 128, 128, 256 1024        leaky_re_lu_75[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)      (None, 128, 128, 128 0           model1_convtrans2[0][0]
# __________________________________________________________________________________________________
# model2_convtrans2 (Conv2DTransp (None, 128, 128, 64) 73792       batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# model_convtrans3 (Conv2DTranspo (None, 256, 256, 128 295040      batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 128, 128, 128 512         leaky_re_lu_66[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)      (None, 128, 128, 64) 0           model2_convtrans2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_76 (LeakyReLU)      (None, 256, 256, 128 0           model_convtrans3[0][0]
# __________________________________________________________________________________________________
# model1_convtrans3 (Conv2DTransp (None, 256, 256, 64) 73792       batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 128, 128, 64) 256         leaky_re_lu_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 256, 256, 128 512         leaky_re_lu_76[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)      (None, 256, 256, 64) 0           model1_convtrans3[0][0]
# __________________________________________________________________________________________________
# model2_conv_final (Conv2D)      (None, 128, 128, 3)  1731        batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# model_convtrans4 (Conv2DTranspo (None, 512, 512, 64) 73792       batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 256, 256, 64) 256         leaky_re_lu_67[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 128, 128, 3)  0           model2_conv_final[0][0]
#                                                                  up_image2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_77 (LeakyReLU)      (None, 512, 512, 64) 0           model_convtrans4[0][0]
# __________________________________________________________________________________________________
# model1_conv_final (Conv2D)      (None, 256, 256, 3)  1731        batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# resizing_4 (Resizing)           (None, 256, 256, 3)  0           add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 512, 512, 64) 256         leaky_re_lu_77[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 256, 256, 3)  0           model1_conv_final[0][0]
#                                                                  resizing_4[0][0]
# __________________________________________________________________________________________________
# model_conv_final (Conv2D)       (None, 512, 512, 3)  1731        batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# resizing_5 (Resizing)           (None, 512, 512, 3)  0           add_7[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 512, 512, 3)  0           model_conv_final[0][0]
#                                                                  resizing_5[0][0]
# ==================================================================================================
# Total params: 16,456,137
# Trainable params: 16,445,961
# Non-trainable params: 10,176
# __________________________________________________________________________________________________

# %%
model.save('arch.hdf5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# c:\python36\vens\tf2-env\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
